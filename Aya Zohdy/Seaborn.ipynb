# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#in pandas we should count the no. of female and male first, then visulize it
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['sex'].value_counts().plot()
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(df, x='sex');

# %%
sns.countplot(df, y='sex');

# %%
sns.countplot(df, x='sex', state= 'precent');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.countplot(df, x='sex', state= 'precent');
#
# File ~\miniconda3\Lib\site-packages\seaborn\categorical.py:2661, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2659 saturation = saturation if fill else 1
#    2660 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 2661 color = _default_color(ax.bar, hue, color, kwargs, saturation)
#    2663 count_axis = {"x": "y", "y": "x"}[p.orient]
#    2664 if p.input_format == "wide":
#
# File ~\miniconda3\Lib\site-packages\seaborn\utils.py:127, in _default_color(method, hue, color, kws, saturation)
#     122     scout.remove()
#     124 elif method.__name__ == "bar":
#     125
# ...

# %%
#Compere between differet columns

sns.countplot(df, x='sex', hue='smoker');

# %%
sns.countplot(df, x='time', hue='day');

# %%
sns.countplot(df, x='day', hue='time', dodge=False);

# %%
df['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
sns.histplot(df, x='tip');

# %%
#add another column

sns.histplot(df, x='tip', hue= 'sex');

# %%
sns.kdeplot(df, x="tip", hue="sex", multiple="stack");

# %%
sns.boxplot(x=df["tip"]);

# %%
sns.boxplot(y=df["tip"], x=df['day']);

# %%
sns.scatterplot(df, x="total_bill", y="tip");
plt.xlabel('Total bill')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 sns.scatterplot(df, x="total_bill", y="tip");
# ----> 2 plt.xlabel('Total bill')
#
# NameError: name 'plt' is not defined

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))

#bright color = positive correlation
# Out:
# <Axes: >

# %%
sns.countplot

# %%
#To knoe the precentage between 2 columns

df['tip_pr'] =  (df['tip']/ df['total_bill']) * 100
df['tip_pr']
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Name: tip_pr, Length: 244, dtype: float64

# %%
sns.histplot(df, x='tip_pr');

# %%
#correlation of all the data

sns.pairplot(df)

# %%
#2 diagram in 1 picture

plt.subplot(121)
sns.boxplot(x=df["tip"])
